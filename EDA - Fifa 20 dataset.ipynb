# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv(r"C:\Users\Admin\Downloads\players_20.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa["nationality"].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Mauritius                 1
# Barbados                  1
# Macau                     1
# São Tomé & Príncipe       1
# Ethiopia                  1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa["nationality"].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
# making a bar plot for top 5 countries
x= list(fifa["nationality"].value_counts()[0:5].keys())
x
# Out:
# ['England', 'Germany', 'Spain', 'France', 'Argentina']

# %%
y=list(fifa["nationality"].value_counts()[0:5])
y
# Out:
# [1667, 1216, 1035, 984, 886]

# %%
plt.figure(figsize=(6,7))
plt.bar(x,y)
plt.title("Top 5 Countries")
plt.xlabel("Countries")
plt.ylabel("Numberof Players")
plt.plot()
# Out:
# []

# %%
player_salary=fifa[["short_name","wage_eur"]]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=["wage_eur"],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
x1=list(player_salary["short_name"][0:5])
x1
# Out:
# ['L. Messi', 'E. Hazard', 'Cristiano Ronaldo', 'K. De Bruyne', 'A. Griezmann']

# %%
y1=list(player_salary["wage_eur"][0:5])
y1
# Out:
# [565000, 470000, 405000, 370000, 370000]

# %%
plt.figure(figsize=(8,5))
plt.bar(x1,y1,color=["red","green","blue","pink","orange"])
plt.show()

# %%
germany = fifa[fifa["nationality"]=="Germany"]

# %%
germany
# Out:
#        sofifa_id                                         player_url  \
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 31        167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37        188350  https://sofifa.com/player/188350/marco-reus/20...
# 49        178603  https://sofifa.com/player/178603/mats-hummels/...
# ...          ...                                                ...
# 18123     252076  https://sofifa.com/player/252076/lukas-schelle...
# 18156     251856  https://sofifa.com/player/251856/dominik-meise...
# 18186     243537  https://sofifa.com/player/243537/maximilian-br...
# 18191     244043  https://sofifa.com/player/244043/nico-stephan/...
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
#
#             short_name              long_name  age         dob  height_cm  \
# 6        M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# ...

# %%
germany.sort_values(by=["height_cm"],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# ...          ...                                                ...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 6364      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 15960     247284  https://sofifa.com/player/247284/patrick-finge...
# 11380     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# ...

# %%
germany.sort_values(by=["weight_kg"],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# ...          ...                                                ...
# 17276     248583  https://sofifa.com/player/248583/sinisa-spreca...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 13387     252559  https://sofifa.com/player/252559/volkan-egri/2...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 17879     244094  https://sofifa.com/player/244094/leonard-langh...
#
#            short_name           long_name  age         dob  height_cm  \
# 13576    L. Watkowiak     Lukas Watkowiak   23  1996-03-06        197
# ...

# %%
germany[["short_name","wage_eur"]].sort_values(by=["wage_eur"],ascending=False)
# all values

# this type of code is used to get only 2 colums and avoid all the others
# Out:
#           short_name  wage_eur
# 36          T. Kroos    330000
# 6      M. ter Stegen    250000
# 55           L. Sané    195000
# 146      I. Gündoğan    180000
# 70         T. Müller    170000
# ...              ...       ...
# 13488  J. Gerezgiher      1000
# 13463       T. Bonga      1000
# 13458      L. Jensen      1000
# 13373    L. Gottwalt      1000
# 18197     M. Harsman      1000
#
# [1216 rows x 2 columns]

# %%
# only top 5 highest paid german foorballers
germany[["short_name","wage_eur"]][0:5].sort_values(by=["wage_eur"],ascending=False)
# Out:
#        short_name  wage_eur
# 36       T. Kroos    330000
# 6   M. ter Stegen    250000
# 37        M. Reus    170000
# 31       M. Neuer    155000
# 49     M. Hummels    130000

# %%
#  players with highest shooting value
player_shooting=fifa[["short_name","shooting"]]
player_shooting
# Out:
#               short_name  shooting
# 0               L. Messi      92.0
# 1      Cristiano Ronaldo      93.0
# 2              Neymar Jr      85.0
# 3               J. Oblak       NaN
# 4              E. Hazard      83.0
# ...                  ...       ...
# 18273         Shao Shuai      23.0
# 18274       Xiao Mingjie      24.0
# 18275          Zhang Wei      35.0
# 18276       Wang Haijian      35.0
# 18277         Pan Ximing      32.0
#
# [18278 rows x 2 columns]

# %%
player_shooting.head(10)
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0
# 5       K. De Bruyne      86.0
# 6      M. ter Stegen       NaN
# 7        V. van Dijk      60.0
# 8          L. Modrić      76.0
# 9           M. Salah      86.0

# %%
player_shooting.sort_values(by=["shooting"],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
# DEFENDING

# %%
defender=fifa[["short_name","defending","nationality","club"]]

# %%
defender.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
defender.sort_values(by=["defending"],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
real_madrid= fifa[fifa["club"]=="Real Madrid"]

# %%
real_madrid
# Out:
#        sofifa_id                                         player_url  \
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28        192119  https://sofifa.com/player/192119/thibaut-court...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 53        193041  https://sofifa.com/player/193041/keylor-navas/...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# ...

# %%
real_madrid[["short_name","wage_eur"]].sort_values(by=["wage_eur"],ascending=False).head()
# Out:
#       short_name  wage_eur
# 4      E. Hazard    470000
# 8      L. Modrić    340000
# 36      T. Kroos    330000
# 18  Sergio Ramos    300000
# 46    K. Benzema    285000

# %%
real_madrid[["short_name","shooting"]].sort_values(by=["shooting"],ascending=False).head()
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %%
real_madrid[["short_name","pace"]].sort_values(by=["pace"],ascending=False).head()
# Out:
#        short_name  pace
# 568  Vinícius Jr.  93.0
# 4       E. Hazard  91.0
# 100       G. Bale  91.0
# 437     Odriozola  89.0
# 424      F. Mendy  89.0

# %%
real_madrid["nationality"].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Costa Rica             1
# Germany                1
# Uruguay                1
# Japan                  1
# Serbia                 1
# Wales                  1
# Colombia               1
# Dominican Republic     1
# Croatia                1
# Name: nationality, dtype: int64

# %%
x5= list(real_madrid["nationality"].value_counts()[0:5].keys())
x5
# Out:
# ['Spain', 'Brazil', 'France', 'Belgium', 'Costa Rica']

# %%
y5= list(real_madrid["nationality"].value_counts()[0:5])
y5
# Out:
# [13, 6, 3, 2, 1]

# %%
plt.figure(figsize=(5,6))
plt.bar(x5,y5,color=["red","yellow","blue","green","orange"])
plt.title("Nationality in Real Madrid")
plt.xlabel("country")
plt.ylabel("number of players")
plt.show()
